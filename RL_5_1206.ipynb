# %% [markdown]
# <a href="https://colab.research.google.com/github/Sprusheeth/RL/blob/main/RL_5_1206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gymnasium

# %%
import gymnasium as gym
import numpy as np

def run_random_agent(env_name, num_episodes=10):
    env = gym.make(env_name)
    total_rewards = []

    print(f"=== Running Random Agent on {env_name} ===")
    print(f"Action Space: {env.action_space}")
    print(f"Observation Space: {env.observation_space}\n")

    for episode in range(1, num_episodes + 1):
        state, info = env.reset()
        done = False
        truncated = False
        episode_reward = 0

        while not (done or truncated):
            action = env.action_space.sample()
            next_state, reward, done, truncated, info = env.step(action)
            episode_reward += reward
            state = next_state

        total_rewards.append(episode_reward)
        print(f"Episode {episode}: Total Reward = {episode_reward}")

    env.close()

    avg_reward = np.mean(total_rewards)
    print(f"\nSummary for {env_name}:")
    print(f"Total Cumulative Reward over {num_episodes} episodes: {sum(total_rewards)}")
    print(f"Average Reward per episode: {avg_reward:.2f}\n" + "="*40 + "\n")
    return total_rewards

# %%
cartpole_rewards = run_random_agent("CartPole-v1")
mountaincar_rewards = run_random_agent("MountainCar-v0")
frozenlake_rewards = run_random_agent("FrozenLake-v1")
# Out:
# === Running Random Agent on CartPole-v1 ===
# Action Space: Discrete(2)
# Observation Space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
#
# Episode 1: Total Reward = 18.0
# Episode 2: Total Reward = 49.0
# Episode 3: Total Reward = 24.0
# Episode 4: Total Reward = 15.0
# Episode 5: Total Reward = 21.0
# Episode 6: Total Reward = 25.0
# Episode 7: Total Reward = 10.0
# Episode 8: Total Reward = 16.0
# Episode 9: Total Reward = 30.0
# Episode 10: Total Reward = 19.0
#
# Summary for CartPole-v1:
# Total Cumulative Reward over 10 episodes: 227.0
# Average Reward per episode: 22.70
# ...
#
# === Running Random Agent on MountainCar-v0 ===
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
#
# Episode 1: Total Reward = -200.0
# Episode 2: Total Reward = -200.0
# Episode 3: Total Reward = -200.0
# Episode 4: Total Reward = -200.0
# Episode 5: Total Reward = -200.0
# ...
